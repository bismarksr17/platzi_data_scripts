# %%
import pandas as pd

# %%
df = pd.read_csv('file_csv.csv')

# %%
# CABECERA DEL DF
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# COLA DEL DF
df.tail()
# Out:
#                                                   Name       Author  \
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 0                        10-Day Green Smoothie Cleanse     JJ Smith
# 0                        10-Day Green Smoothie Cleanse     JJ Smith
# 0                        10-Day Green Smoothie Cleanse     JJ Smith
# 0                        10-Day Green Smoothie Cleanse     JJ Smith
#
#      User Rating  Reviews  Price  Year        Genre
# 549          4.7    14331      8  2019  Non Fiction
# 0            4.7    17350      8  2016  Non Fiction
# 0            4.7    17350      8  2016  Non Fiction
# 0            4.7    17350      8  2016  Non Fiction
# 0            4.7    17350      8  2016  Non Fiction

# %%
# RETORNA INFORMACION DEL DF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 554 entries, 0 to 0
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         554 non-null    object
#  1   Author       554 non-null    object
#  2   User Rating  554 non-null    float64
#  3   Reviews      554 non-null    int64
#  4   Price        554 non-null    int64
#  5   Year         554 non-null    int64
#  6   Genre        554 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 34.6+ KB

# %%
# DATOS ESTADISTICOS DE LOS CAMPOS NUMERICOS DEL DF
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
# A NIVEL TECNICO, CUANTO DE ESPACIO DE MEMORIA SE ESTA UTILIZANDO POR COLUMNA
df.memory_usage(deep=True)
# Out:
# Index            128
# Name           59737
# Author         39078
# User Rating     4400
# Reviews         4400
# Price           4400
# Year            4400
# Genre          36440
# dtype: int64

# %%
# CONTEO DE CUANTAS VECES SE ENCUENTRA REGISTRADO UN DATOS DE UNA COLUMNA DETERMINADA
df['Author'].value_counts()
# Out:
# Jeff Kinney                           12
# Gary Chapman                          11
# Rick Riordan                          11
# Suzanne Collins                       11
# American Psychological Association    10
#                                       ..
# Keith Richards                         1
# Chris Cleave                           1
# Alice Schertle                         1
# Celeste Ng                             1
# Adam Gasiewski                         1
# Name: Author, Length: 248, dtype: int64

# %%
# CREAMOS UN FILA DUPLICADA EN EL DF
primera_fila = df.iloc[0]
df = df.append(primera_fila)
df
# Out:
# /tmp/ipykernel_143/1519446370.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(primera_fila)
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 0                        10-Day Green Smoothie Cleanse
# 0                        10-Day Green Smoothie Cleanse
# 0                        10-Day Green Smoothie Cleanse
# 0                        10-Day Green Smoothie Cleanse
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# ...

# %%
# ELIMINAMOS DUPLICADO, DEJA POR DEFECTO EL PRIMER REGISTRO
df.drop_duplicates()
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# ELIMINA LOS DUPLICADOS, DEJA EL ULTIMO REGISTRO INGRESADO
df.drop_duplicates(keep='last')
# Out:
#                                                   Name  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# ..                                                 ...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 0                        10-Day Green Smoothie Cleanse
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# ...

# %%
# ORDENA LOS DATOS EN BASE A UN COLUMNA, YA SEA ASCENDENTE O ASCENDENTE
df.sort_values('Year', ascending=False)
# Out:
#                                                   Name            Author  \
# 291  Salt, Fat, Acid, Heat: Mastering the Elements ...      Samin Nosrat
# 240  National Geographic Little Kids First Big Book...       Amy Shields
# 128  Girl, Stop Apologizing: A Shame-Free Plan for ...     Rachel Hollis
# 426  The Life-Changing Magic of Tidying Up: The Jap...       Marie Kondō
# 491                                   The Wonky Donkey       Craig Smith
# ..                                                 ...               ...
# 387         The Girl Who Played with Fire (Millennium)     Stieg Larsson
# 520                            Under the Dome: A Novel      Stephen King
# 388  The Girl with the Dragon Tattoo (Millennium Se...     Stieg Larsson
# 25   Arguing with Idiots: How to Stop Small Minds a...        Glenn Beck
# 369  The Five Dysfunctions of a Team: A Leadership ...  Patrick Lencioni
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    string
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(2), string(1)
# memory usage: 30.2+ KB

# %%
# CAMBIA EL TIPO DE DATOS DE LA COLUMNA INDICADA
df['Author'] = df['Author'].astype('string')
